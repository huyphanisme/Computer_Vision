# %%
from PIL import Image

# %%
from imgtools import *

# %%
dir = "D:/Computer_Vision/Computer_Vision/Images"

# %%
imgs =  get_image_list(dir)

# %%
#Hiển thị ảnh
for img in imgs:
    print(img.size)
    display(img)
# Out:
# (330, 153)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=330x153>
# (346, 180)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=346x180>
# (260, 194)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=260x194>
# (330, 153)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=330x153>
# (330, 153)
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=330x153>
