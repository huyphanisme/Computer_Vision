# %%
from PIL import Image
from imgtools import *
from IPython.display import display

# %%
dir = "D:/Computer_Vision/Computer_Vision/Images/Hinh1.jpg"

# %%
img = load_image(dir)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=330x153>

# %%
# Định vị khu vực cắt
region = (100, 75, 175, 160)
# Cắt vùng ảnh
cropped_image = img.crop(region)
display(cropped_image)
# Out:
# <PIL.Image.Image image mode=RGB size=75x85>

# %%
paste_position = (180, 130)
img.paste(cropped_image, paste_position)
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=330x153>
