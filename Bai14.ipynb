# %%
import numpy as np
from PIL import Image

def average_images(image_list):
    total_array = np.array(Image.open(image_list[0]), 'f')
    count=1

    for image_path in image_list[1:]:
        try:
            image_array = np.array(Image.open(image_path), 'f')
            total_array += image_array
            count=count+1
        except:
            print("Skip ", image_path);

    # Tính trung bình
    average_array = total_array / count

    # Chuyển đổi kết quả trung bình thành hình ảnh
    average_image = Image.fromarray(average_array.astype('uint8'))

    return average_image

# Sử dụng ví dụ:
my_path_1 = "D:/Computer_Vision/Computer_Vision/Images/Hinh1.jpg"
my_path_2 = "D:/Computer_Vision/Computer_Vision/Images/Hinh2.jpg"
image_list = [my_path_1, my_path_2]
result_image = average_images(image_list)
display(result_image)


# Sử dụng ví dụ:
my_path_1 = "D:/Computer_Vision/Computer_Vision/Images/Hinh3.jpg"
my_path_2 = "D:/Computer_Vision/Computer_Vision/Images/Hinh4.jpg"
image_list = [my_path_1, my_path_2]
result_image = average_images(image_list)
display(result_image)
# Out:
# Skip  D:/Computer_Vision/Computer_Vision/Images/Hinh2.jpg
# <PIL.Image.Image image mode=RGB size=330x153>
# Skip  D:/Computer_Vision/Computer_Vision/Images/Hinh4.jpg
# <PIL.Image.Image image mode=RGB size=260x194>
