# %%
from PIL import Image

# %%
dir = "D:/Computer_Vision/Computer_Vision/Images"

# %%
image_path = dir +'/Hinh1.JPG'
print(image_path)
# Out:
# D:/Computer_Vision/Computer_Vision/Images/Hinh1.JPG

# %%
img01 = Image.open(image_path)

# %%
display(img01)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=330x153>

# %%
print("Định dang ảnh: ", img01.format)
# Out:
# Định dang ảnh:  JPEG

# %%
print("Kích thước hình ảnh: ", img01.size)
# Out:
# Kích thước hình ảnh:  (330, 153)

# %%
new_img_01_path = dir + '/new_01.JPG'
new_img_png_01_path = dir + '/new_01.PNG'
img01.save(new_img_01_path)
img01.save(new_img_png_01_path)

# %%
img01.close()
